# %%
import pandas as pd
import numpy as np
data = [
    {
        'key': 'AUMA',
        'year': 2015, 
        'month': 5,
        'title': "Machine learning based auto-tuning for enhanced OpenCL performance portability", 
        'framework': 'AUMA', 
        'searchspaces': 
            [
                { 'kernel': 'Convolution', 'size': 131072 },
                { 'kernel': 'Raycasting', 'size': 655360 },
                { 'kernel': 'Stereo', 'size': 2359296 },
            ] 
    },
    {
        'key': 'CLTune2015',
        'year': 2015, 
        'month': 9,
        'title': "CLTune: A Generic Auto-Tuner for OpenCL Kernels", 
        'framework': 'CLTune', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 995328 },
                { 'kernel': 'Convolution', 'size': 3424 }
            ] 
    },
    {
        'key': 'KTT',
        'year': 2017, 
        'month': 9,
        'title': "Autotuning of OpenCL kernels with global optimizations", 
        'framework': 'KTT', 
        'searchspaces': 
            [
                { 'kernel': 'Coulomb', 'size': 14784 },
                { 'kernel': 'Reduction', 'size': 2640 }
            ] 
    },
    {
        'key': 'KT2019',
        'year': 2019, 
        'month': 1,
        'title': "Kernel Tuner: A search-optimizing GPU code auto-tuner", 
        'framework': 'Kernel Tuner', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 5788 }, 
                { 'kernel': 'Point-in-Polygon', 'size': 8184 },
                { 'kernel': 'Convolution', 'size': 1496 }
            ] 
    },
    {
        'key': 'KTTbench2020',
        'year': 2020, 
        'month': 7,
        'title': "A benchmark set of highly-efficient CUDA and OpenCL kernels and its dynamic autotuning with Kernel Tuning Toolkit", 
        'framework': 'KTT', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 241600 }, 
                { 'kernel': 'BiCG', 'size': 5122 },
                { 'kernel': 'Convolution', 'size': 5248 },
                { 'kernel': 'Coulomb 3D', 'size': 1260 },
                { 'kernel': 'Convolution', 'size': 5248 },
                { 'kernel': 'Hotspot', 'size': 480 },
                { 'kernel': 'Transpose', 'size': 10752 },
                { 'kernel': 'N-body', 'size': 9408 },
                { 'kernel': 'Reduction', 'size': 175 },
                { 'kernel': 'Fourier', 'size': 360 }
            ]
    },
    {
        'key': 'BO2021',
        'year': 2021, 
        'month': 11,
        'title': "Bayesian Optimization for auto-tuning GPU kernels", 
        'framework': 'Kernel Tuner', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 17956 }, 
                { 'kernel': 'Point-in-Polygon', 'size': 8184 },
                { 'kernel': 'Convolution', 'size': 9400 }
            ] 
    },
    {
        'key': 'KTbench2022',
        'year': 2022, 
        'month': 9,
        'title': "Benchmarking optimization algorithms for auto-tuning GPU kernels", 
        'framework': 'Kernel Tuner', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 82944 }, 
                { 'kernel': 'Point-in-Polygon', 'size': 8184 },
                { 'kernel': 'Convolution', 'size': 18432 }
            ] 
    },
    {
        'key': 'GG2022',
        'year': 2022, 
        'title': "Going green: optimizing GPUs for energy efficiency through model-steered auto-tuning", 
        'month': 11,
        'framework': 'Kernel Tuner', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 17472 },
            ] 
    },
    {
        'key': 'BAT2023',
        'year': 2023, 
        'month': 5,
        'title': "Towards a Benchmarking Suite for Kerneltuners (accepted at iWAPT 2023)", 
        'framework': 'Kernel Tuner', 
        'searchspaces': 
            [
                { 'kernel': 'GEMM', 'size': 17956 },
                { 'kernel': 'Point-in-Polygon', 'size': 4092 },
                { 'kernel': 'N-body', 'size': 1568 },
                { 'kernel': 'Convolution', 'size': 9400 },
                { 'kernel': 'ExpDist', 'size': 540000 },
                { 'kernel': 'Hotspot', 'size': 21850147 },
                { 'kernel': 'Dedispersion', 'size': 107011905 },
            ] 
    },
    {
        'key': 'KL2023',
        'year': 2023, 
        'month': 8,
        'title': "Kernel Launcher: C++ Library for Optimal-Performance Portable CUDA Applications", 
        'framework': 'Kernel Tuner', 
        'searchspaces': 
            [
                { 'kernel': 'MicroHH', 'size': 7700000 },
            ] 
    },
    {
        'key': 'BaCO2024',
        'year': 2024, 
        'month': 2,
        'title': "BaCO: a fast and portable bayesian compiler optimization framework", 
        'framework': 'BaCO',
        'searchspaces': 
            [
                # TACO
                { 'kernel': 'SpMV', 'size': 3000000 },
                { 'kernel': 'SpMM', 'size': 47000 },
                { 'kernel': 'SDDMM', 'size': 78000 },
                { 'kernel': 'TTV', 'size': 6000000 },
                { 'kernel': 'MTTKRP', 'size': 680000 },
                # RISE & ELEVATE
                { 'kernel': 'MM_CPU', 'size': 29000 },
                { 'kernel': 'MM_GPU', 'size': 150000000 },
                { 'kernel': 'Asum_GPU', 'size': 63000 },
                { 'kernel': 'Scal_GPU', 'size': 4200000 },
                { 'kernel': 'K-means_GPU', 'size': 3600 },
                { 'kernel': 'Harris_GPU', 'size': 10000000 },
                { 'kernel': 'Stencil_GPU', 'size': 3600 },
                # HPVM2FPGA
                { 'kernel': 'BFS', 'size': 256 },
                { 'kernel': 'Audio', 'size': 840000 },
                { 'kernel': 'PreEuler', 'size': 15000 },
            ] 
    },
    # {
    #     'key': 'KT2024',
    #     'year': 2024, 
    #     'month': 10,
    #     'title': "Efficient Auto-Tuning of Large Searchspaces with Kernel Tuner", 
    #     'framework': 'Kernel Tuner', 
    #     'searchspaces': 
    #         [
    #             { 'kernel': 'Dedispersion', 'size': 22272 },
    #             { 'kernel': 'Expdist', 'size': 9732096 },
    #             { 'kernel': 'Hotspot', 'size': 22200000 },
    #             { 'kernel': 'MicroHH', 'size': 1166400 },
    #         ] 
    # },
]

expanded_data = []
cumulative_sizes = []
for d in data:
    expanded = d.copy()
    if 'month' not in expanded:
        expanded['month'] = 6
    expanded['yearfloat'] = expanded['year'] + round(expanded['month'] / 12, 2)
    expanded.pop('searchspaces')
    sizes = [s['size'] for s in d['searchspaces']]
    cumulative_sizes = cumulative_sizes + sizes
    expanded['average'] = np.mean(sizes)
    expanded['cumulative average'] = np.mean(cumulative_sizes)
    for s in d['searchspaces']:
        for k, v in s.items():
            expanded[k] = v
        expanded_data.append(expanded.copy())

df = pd.DataFrame(expanded_data)
df
# Out:
#              key  year  month  \
# 0           AUMA  2015      5
# 1           AUMA  2015      5
# 2           AUMA  2015      5
# 3     CLTune2015  2015      9
# 4     CLTune2015  2015      9
# 5            KTT  2017      9
# 6            KTT  2017      9
# 7         KT2019  2019      1
# 8         KT2019  2019      1
# 9         KT2019  2019      1
# 10  KTTbench2020  2020      7
# 11  KTTbench2020  2020      7
# 12  KTTbench2020  2020      7
# 13  KTTbench2020  2020      7
# 14  KTTbench2020  2020      7
# 15  KTTbench2020  2020      7
# 16  KTTbench2020  2020      7
# 17  KTTbench2020  2020      7
# 18  KTTbench2020  2020      7
# 19  KTTbench2020  2020      7
# 20        BO2021  2021     11
# 21        BO2021  2021     11
# 22        BO2021  2021     11
# 23   KTbench2022  2022      9
# 24   KTbench2022  2022      9
# 25   KTbench2022  2022      9
# 26        GG2022  2022     11
# 27       BAT2023  2023      5
# 28       BAT2023  2023      5
# 29       BAT2023  2023      5
# 30       BAT2023  2023      5
# 31       BAT2023  2023      5
# 32       BAT2023  2023      5
# 33       BAT2023  2023      5
# 34        KL2023  2023      8
# 35      BaCO2024  2024      2
# 36      BaCO2024  2024      2
# 37      BaCO2024  2024      2
# 38      BaCO2024  2024      2
# 39      BaCO2024  2024      2
# 40      BaCO2024  2024      2
# 41      BaCO2024  2024      2
# 42      BaCO2024  2024      2
# 43      BaCO2024  2024      2
# 44      BaCO2024  2024      2
# 45      BaCO2024  2024      2
# 46      BaCO2024  2024      2
# 47      BaCO2024  2024      2
# 48      BaCO2024  2024      2
# 49      BaCO2024  2024      2
#
#                                                 title     framework  \
# 0   Machine learning based auto-tuning for enhance...          AUMA
# 1   Machine learning based auto-tuning for enhance...          AUMA
# 2   Machine learning based auto-tuning for enhance...          AUMA
# 3     CLTune: A Generic Auto-Tuner for OpenCL Kernels        CLTune
# 4     CLTune: A Generic Auto-Tuner for OpenCL Kernels        CLTune
# 5   Autotuning of OpenCL kernels with global optim...           KTT
# 6   Autotuning of OpenCL kernels with global optim...           KTT
# 7   Kernel Tuner: A search-optimizing GPU code aut...  Kernel Tuner
# 8   Kernel Tuner: A search-optimizing GPU code aut...  Kernel Tuner
# 9   Kernel Tuner: A search-optimizing GPU code aut...  Kernel Tuner
# 10  A benchmark set of highly-efficient CUDA and O...           KTT
# 11  A benchmark set of highly-efficient CUDA and O...           KTT
# 12  A benchmark set of highly-efficient CUDA and O...           KTT
# 13  A benchmark set of highly-efficient CUDA and O...           KTT
# 14  A benchmark set of highly-efficient CUDA and O...           KTT
# 15  A benchmark set of highly-efficient CUDA and O...           KTT
# 16  A benchmark set of highly-efficient CUDA and O...           KTT
# 17  A benchmark set of highly-efficient CUDA and O...           KTT
# 18  A benchmark set of highly-efficient CUDA and O...           KTT
# 19  A benchmark set of highly-efficient CUDA and O...           KTT
# 20  Bayesian Optimization for auto-tuning GPU kernels  Kernel Tuner
# 21  Bayesian Optimization for auto-tuning GPU kernels  Kernel Tuner
# 22  Bayesian Optimization for auto-tuning GPU kernels  Kernel Tuner
# 23  Benchmarking optimization algorithms for auto-...  Kernel Tuner
# 24  Benchmarking optimization algorithms for auto-...  Kernel Tuner
# 25  Benchmarking optimization algorithms for auto-...  Kernel Tuner
# 26  Going green: optimizing GPUs for energy effici...  Kernel Tuner
# 27  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 28  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 29  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 30  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 31  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 32  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 33  Towards a Benchmarking Suite for Kerneltuners ...  Kernel Tuner
# 34  Kernel Launcher: C++ Library for Optimal-Perfo...  Kernel Tuner
# 35  BaCO: a fast and portable bayesian compiler op...          BaCO
# 36  BaCO: a fast and portable bayesian compiler op...          BaCO
# 37  BaCO: a fast and portable bayesian compiler op...          BaCO
# 38  BaCO: a fast and portable bayesian compiler op...          BaCO
# 39  BaCO: a fast and portable bayesian compiler op...          BaCO
# 40  BaCO: a fast and portable bayesian compiler op...          BaCO
# 41  BaCO: a fast and portable bayesian compiler op...          BaCO
# 42  BaCO: a fast and portable bayesian compiler op...          BaCO
# 43  BaCO: a fast and portable bayesian compiler op...          BaCO
# 44  BaCO: a fast and portable bayesian compiler op...          BaCO
# 45  BaCO: a fast and portable bayesian compiler op...          BaCO
# 46  BaCO: a fast and portable bayesian compiler op...          BaCO
# 47  BaCO: a fast and portable bayesian compiler op...          BaCO
# 48  BaCO: a fast and portable bayesian compiler op...          BaCO
# 49  BaCO: a fast and portable bayesian compiler op...          BaCO
#
#     yearfloat       average  cumulative average            kernel       size
# 0     2015.42  1.048576e+06        1.048576e+06       Convolution     131072
# 1     2015.42  1.048576e+06        1.048576e+06        Raycasting     655360
# 2     2015.42  1.048576e+06        1.048576e+06            Stereo    2359296
# 3     2015.75  4.993760e+05        8.288960e+05              GEMM     995328
# 4     2015.75  4.993760e+05        8.288960e+05       Convolution       3424
# 5     2017.75  8.712000e+03        5.945577e+05           Coulomb      14784
# 6     2017.75  8.712000e+03        5.945577e+05         Reduction       2640
# 7     2019.08  5.156000e+03        4.177372e+05              GEMM       5788
# 8     2019.08  5.156000e+03        4.177372e+05  Point-in-Polygon       8184
# 9     2019.08  5.156000e+03        4.177372e+05       Convolution       1496
# 10    2020.58  2.796530e+04        2.228512e+05              GEMM     241600
# 11    2020.58  2.796530e+04        2.228512e+05              BiCG       5122
# 12    2020.58  2.796530e+04        2.228512e+05       Convolution       5248
# 13    2020.58  2.796530e+04        2.228512e+05        Coulomb 3D       1260
# 14    2020.58  2.796530e+04        2.228512e+05       Convolution       5248
# 15    2020.58  2.796530e+04        2.228512e+05           Hotspot        480
# 16    2020.58  2.796530e+04        2.228512e+05         Transpose      10752
# 17    2020.58  2.796530e+04        2.228512e+05            N-body       9408
# 18    2020.58  2.796530e+04        2.228512e+05         Reduction        175
# 19    2020.58  2.796530e+04        2.228512e+05           Fourier        360
# 20    2021.92  1.184667e+04        1.953289e+05              GEMM      17956
# 21    2021.92  1.184667e+04        1.953289e+05  Point-in-Polygon       8184
# 22    2021.92  1.184667e+04        1.953289e+05       Convolution       9400
# 23    2022.75  3.652000e+04        1.770048e+05              GEMM      82944
# 24    2022.75  3.652000e+04        1.770048e+05  Point-in-Polygon       8184
# 25    2022.75  3.652000e+04        1.770048e+05       Convolution      18432
# 26    2022.92  1.747200e+04        1.710962e+05              GEMM      17472
# 27    2023.42  1.849072e+07        3.942784e+06              GEMM      17956
# 28    2023.42  1.849072e+07        3.942784e+06  Point-in-Polygon       4092
# 29    2023.42  1.849072e+07        3.942784e+06            N-body       1568
# 30    2023.42  1.849072e+07        3.942784e+06       Convolution       9400
# 31    2023.42  1.849072e+07        3.942784e+06           ExpDist     540000
# 32    2023.42  1.849072e+07        3.942784e+06           Hotspot   21850147
# 33    2023.42  1.849072e+07        3.942784e+06      Dedispersion  107011905
# 34    2023.67  7.700000e+06        4.050133e+06           MicroHH    7700000
# 35    2024.17  1.166396e+07        6.334282e+06              SpMV    3000000
# 36    2024.17  1.166396e+07        6.334282e+06              SpMM      47000
# 37    2024.17  1.166396e+07        6.334282e+06             SDDMM      78000
# 38    2024.17  1.166396e+07        6.334282e+06               TTV    6000000
# 39    2024.17  1.166396e+07        6.334282e+06            MTTKRP     680000
# 40    2024.17  1.166396e+07        6.334282e+06            MM_CPU      29000
# 41    2024.17  1.166396e+07        6.334282e+06            MM_GPU  150000000
# 42    2024.17  1.166396e+07        6.334282e+06          Asum_GPU      63000
# 43    2024.17  1.166396e+07        6.334282e+06          Scal_GPU    4200000
# 44    2024.17  1.166396e+07        6.334282e+06       K-means_GPU       3600
# 45    2024.17  1.166396e+07        6.334282e+06        Harris_GPU   10000000
# 46    2024.17  1.166396e+07        6.334282e+06       Stencil_GPU       3600
# 47    2024.17  1.166396e+07        6.334282e+06               BFS        256
# 48    2024.17  1.166396e+07        6.334282e+06             Audio     840000
# 49    2024.17  1.166396e+07        6.334282e+06          PreEuler      15000

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.patches
mpl.rcParams['figure.dpi'] = 300

levels, categories = pd.factorize(df['key'])
colors = [plt.cm.tab10(i) for i in levels] # using the "tab10" colormap
handles = [matplotlib.patches.Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

plt.scatter(df['yearfloat'], df['size'], c=colors)
# plt.plot(df['yearfloat'], df['cumulative average'], color='grey', linestyle='dashed', linewidth=1, label='Cumulative mean')
plt.yscale('log')
plt.gca().set(xlabel='Publication year', ylabel='Searchspace size')
plt.xticks(np.arange(df['year'].min(), df['year'].max()+1, 1))
# plt.legend(handles=handles, title='Paper')
# plt.legend()
# Out:
# ([<matplotlib.axis.XTick at 0x1232dd130>,
#   <matplotlib.axis.XTick at 0x123292fc0>,
#   <matplotlib.axis.XTick at 0x12334c290>,
#   <matplotlib.axis.XTick at 0x12334cc80>,
#   <matplotlib.axis.XTick at 0x12334d6a0>,
#   <matplotlib.axis.XTick at 0x12334deb0>,
#   <matplotlib.axis.XTick at 0x1232f01d0>,
#   <matplotlib.axis.XTick at 0x1231f9730>,
#   <matplotlib.axis.XTick at 0x123267290>,
#   <matplotlib.axis.XTick at 0x1232901d0>],
#  [Text(2015, 0, '2015'),
#   Text(2016, 0, '2016'),
#   Text(2017, 0, '2017'),
#   Text(2018, 0, '2018'),
#   Text(2019, 0, '2019'),
#   Text(2020, 0, '2020'),
#   Text(2021, 0, '2021'),
#   Text(2022, 0, '2022'),
#   Text(2023, 0, '2023'),
#   Text(2024, 0, '2024')])
